# %% [markdown]
# # Lab 1: Try LLM APIs

# %% [markdown]
# ## You will learn:
# - First experience how to do run program on the cloud
# - Learn how to manage API keys
# - Frist experience of using different LLM APIs
# - (If you haven't used it before), how to use Jupyter Notebook in VSCode

# %% [markdown]
# ## 0 Preparations

# %% [markdown]
# ### 0.1 Dependencies

# %%
# requirements.txt contains the basic packages needed to implement this project
# We have installed all dependencies in the default image, so you do not have to install them again, if you use the default image.
#!pip install -r requirements.txt

# %% [markdown]
# ### 0.2 Proxy to access OpenAI

# %%
# add proxy to access openai ...
import os
os.environ['HTTP_PROXY']="http://Clash:QOAF8Rmd@10.1.0.213:7890"
os.environ['HTTPS_PROXY']="http://Clash:QOAF8Rmd@10.1.0.213:7890"
os.environ['ALL_PROXY']="socks5://Clash:QOAF8Rmd@10.1.0.213:7893"

# %% [markdown]
# ### 0.3 Saving your API token in a .env file
#
# Here we need to use an OpenAI API KEY, and passing the API KEY directly into the code is terrible for security. A more correct way is to use the dotenv package, write the API_KEY to the .env file, and import the API KEY later by loading the environment variable.
#
# You should first create a new file named .env in the root directory of your project.** (AND Never commit it to Git!)
# The content in this file should be stored as key-value pair.  The .env file is simply a text file with one key-value per line like:
#
#     # Comment 1
#     KEY1=value1
#     # Comment 2
#     KEY2=value2
#
# More informations see:
#
# https://pythonjishu.com/ifggzibrpkgavow/

# %% [markdown]
# ##  1 Using OpenAI API

# %% [markdown]
# ### 1.1 Get response from OpenAI

# %%
from dotenv import load_dotenv
import os
load_dotenv()
openai_api_key = os.environ.get("OPENAI_API_KEY")
# print(openai_api_key)  ## if you print it, make sure that you clear the output before commiting the notebook to github.

# %% [markdown]
# Then you can make a call to OpenAI, using the api-key.

# %%
from openai import OpenAI
client = OpenAI(
    base_url = "https://api.openai-proxy.org/v1",
    api_key="sk-HnocdkxY9AHr1YimbdoR8EDFzCp2HoUJ0iKrQ00Da1ICsL16"
    )

response = client.chat.completions.create(
  model="gpt-4-turbo-preview",
  messages=[
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Who won the world series in 2020?"},
    {"role": "assistant", "content": "The Los Angeles Dodgers won the World Series in 2020."},
    {"role": "user", "content": "Where was it played?"}
  ]
)
print(response.choices[0].message.content)
# Out:
# The 2020 World Series was played at Globe Life Field in Arlington, Texas. This was unique because it was the first time in modern history that the World Series was held at a neutral site, a decision made due to the COVID-19 pandemic.

# %%
#### YOUR TASK ####
# You can exlore what information is in the response object by printing it out and examine it
# print(response)ChatCompletion(id='chatcmpl-agfwPRTnh4uBFA9BMu2IgUXZ9N0fL', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The 2020 World Series was played at Globe Life Field in Arlington, Texas. This was unique because it was the first time in modern history that the World Series was held at a neutral site, a decision made due to the COVID-19 pandemic.', role='assistant', function_call=None, tool_calls=None))], created=1710247792, model='gpt-4-0125-preview', object='chat.completion', system_fingerprint='fp_31c0f205d1', usage=CompletionUsage(completion_tokens=51, prompt_tokens=53, total_tokens=104))
# Out:
# ChatCompletion(id='chatcmpl-agfwPRTnh4uBFA9BMu2IgUXZ9N0fL', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The 2020 World Series was played at Globe Life Field in Arlington, Texas. This was unique because it was the first time in modern history that the World Series was held at a neutral site, a decision made due to the COVID-19 pandemic.', role='assistant', function_call=None, tool_calls=None))], created=1710247792, model='gpt-4-0125-preview', object='chat.completion', system_fingerprint='fp_31c0f205d1', usage=CompletionUsage(completion_tokens=51, prompt_tokens=53, total_tokens=104))

# %% [markdown]
# You can learn more about the OpenAI API from https://platform.openai.com/docs/overview

# %% [markdown]
# ## 1.2 Your Task: Use OpenAI api to achieve one shift Caesar cipher communicate
#
# We have already provided you the prompts, and you should consider the instruction and demonstrations, and you should use the model gpt-4-turbo-preview.

# %%
def encode(s):
    for c in s:
        if c not in ' ,.!?':
            c = chr(ord(c) + 1)
        print(c, end='')    
        
def decode(s):
    for c in s:
        if c not in ' ,.!?':
            c = chr(ord(c) - 1)
        print(c, end='')

# %%
encode('What is the capital of France?')
# Out:
# Xibu jt uif dbqjubm pg Gsbodf?

# %%
prompt = """
You are an expert on Caesar Cipher. We will communicate in Caesar. Do not be a translator.

The Caesar Cipher, recognized as one of the pioneer cryptographic methods which ciphertext is to translate each letter of the original text backward by two, and z is translated directly to b. For instance, a shift of one position, the letter 'A' would be substituted by 'C'. you should answer my question in Caesar.

Examples:

User: ipx up nblf b cpnc ?
Assistant: Up nblf b cpnc, zpv gjstu offe up 

User: Xip jt uif qsftjefou pg Dijob ? 
Assistant: Wh Ihmfohmf.

User: Dbo zpv ufmm nf xifsf jt uif dbqjubm pg Dijob ?
Assistant: Cfjkjoh.

User: Dbo zpv ufmm nf xifsf jt uif dbqjubm pg Bnfsjdbo ?
Assistant: Xbtijohupo.

User: Xibu jt uif dbqjubm pg Gsbodf ?"""
encode("What is the capital of Germany?")
print('\n')
encode("Berlin")
print('\n')
encode("What is the capital of China?")
print('\n')
encode("Beijing")
print('\n')
encode("What is the capital of Russia?")
print('\n')
encode("Moscow")
# Out:
# Xibu jt uif dbqjubm pg Hfsnboz?
#
# Cfsmjo
#
# Xibu jt uif dbqjubm pg Dijob?
#
# Cfjkjoh
#
# Xibu jt uif dbqjubm pg Svttjb?
#
# Nptdpx

# %%
#### YOUR TASK ####
# using the gpt-4 model, create a chat response to the prompt above
from openai import OpenAI
client = OpenAI(
    base_url = "https://api.openai-proxy.org/v1",
    api_key="sk-HnocdkxY9AHr1YimbdoR8EDFzCp2HoUJ0iKrQ00Da1ICsL16"
    )

response = client.chat.completions.create(
  model="gpt-4-turbo-preview",
  messages=[
    {"role": "system", "content": "You are an expert on Caesar Cipher. We will communicate in Caesar. Do not be a translator. The Caesar Cipher, recognized as one of the pioneer cryptographic methods which ciphertext is to translate each letter of the original text backward by two, and z is translated directly to b. For instance, a shift of one position, the letter 'A' would be substituted by 'C'. you should answer my question in Caesar.Examples:"},
    {"role": "user", "content": "ipx up nblf b cpnc ?"},
    {"role": "assistant", "content": "Up nblf b cpnc, zpv gjstu offe up."},
    {"role": "user", "content": "Dbo zpv ufmm nf xifsf jt uif dbqjubm pg Dijob ?"},
    {"role": "assistant", "content": "Cfjkjoh."},
    {"role": "user", "content": "Dbo zpv ufmm nf xifsf jt uif dbqjubm pg Bnfsjdbo ?"},
    {"role": "assistant", "content": "Xbtijohupo."},
    {"role": "user", "content": "Xibu jt uif dbqjubm pg Gsbodf ?"}
  ]
)
print(response.choices[0].message.content)
# Out:
# Qbsjt

# %%
#### YOUR TASK ####
### TODO: Print out the cipher text here
# Ibsjt.
### TODO: Print out the clear text here using the decode() function
decode("Qbsjt")
# Paris.
# Out:
# Paris

# %%
#### YOUR TASK ####
### TODO: print out the response object.  Explore the entire response object.  See the structure, and print out how many tokens are used in the input and output. 
print(response)
# ChatCompletion(id='chatcmpl-vSWfh7Ex4TfX4sj0TeaLVPAyJmeU5', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Ibsjt.', role='assistant', function_call=None, tool_calls=None))], created=1710247325, model='gpt-4-0125-preview', object='chat.completion', system_fingerprint='fp_c121a3f431', usage=CompletionUsage(completion_tokens=4, prompt_tokens=251, total_tokens=255))
# 251 tokens in the input; 4 tokens in the output.
# Out:
# ChatCompletion(id='chatcmpl-vSWfh7Ex4TfX4sj0TeaLVPAyJmeU5', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Ibsjt.', role='assistant', function_call=None, tool_calls=None))], created=1710247325, model='gpt-4-0125-preview', object='chat.completion', system_fingerprint='fp_c121a3f431', usage=CompletionUsage(completion_tokens=4, prompt_tokens=251, total_tokens=255))

# %%
#### YOUR TASK ####
### TODO: Repeat the query with another model 'gpt-3.5-turbo'.  Do you still get the same response?
from openai import OpenAI
client = OpenAI(
    base_url = "https://api.openai-proxy.org/v1",
    api_key="sk-HnocdkxY9AHr1YimbdoR8EDFzCp2HoUJ0iKrQ00Da1ICsL16"
    )

response = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are an expert on Caesar Cipher. We will communicate in Caesar. Do not be a translator. The Caesar Cipher, recognized as one of the pioneer cryptographic methods which ciphertext is to translate each letter of the original text backward by two, and z is translated directly to b. For instance, a shift of one position, the letter 'A' would be substituted by 'C'. you should answer my question in Caesar."},
    {"role": "user", "content": "ipx up nblf b cpnc ?"},
    {"role": "assistant", "content": "Up nblf b cpnc, zpv gjstu offe up."},
    {"role": "user", "content": "Dbo zpv ufmm nf xifsf jt uif dbqjubm pg Dijob ?"},
    {"role": "assistant", "content": "Cfjkjoh."},
    {"role": "user", "content": "Dbo zpv ufmm nf xifsf jt uif dbqjubm pg Bnfsjdbo ?"},
    {"role": "assistant", "content": "Xbtijohupo."},
    {"role": "user", "content": "Xibu jt uif dbqjubm pg Gsbodf ?"}
  ]
)
print(response.choices[0].message.content)
decode(response.choices[0].message.content)
# Dijob.
# China.
# Out:
# Dijob.
# China.

# %%
#### YOUR TASK ####
### TODO: (optional) can you let 'gpt-3.5-turbo' to print the same, by adding more examples in the prompt?  
### Consider using a script to generate a much longer prompt with more examples
from openai import OpenAI
client = OpenAI(
    base_url = "https://api.openai-proxy.org/v1",
    api_key="sk-HnocdkxY9AHr1YimbdoR8EDFzCp2HoUJ0iKrQ00Da1ICsL16"
    )

response = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are an expert on Caesar Cipher. We will communicate in Caesar. Do not be a translator. The Caesar Cipher, recognized as one of the pioneer cryptographic methods which ciphertext is to translate each letter of the original text backward by two, and z is translated directly to b. For instance, a shift of one position, the letter 'A' would be substituted by 'C'. you should answer my question in Caesar.Examples:"},
    {"role": "user", "content": "ipx up nblf b cpnc ?"},
    {"role": "assistant", "content": "Up nblf b cpnc, zpv gjstu offe up."},
    {"role": "user", "content": "Dbo zpv ufmm nf xifsf jt uif dbqjubm pg Dijob ?"},
    {"role": "assistant", "content": "Cfjkjoh."},
    {"role": "user", "content": "Dbo zpv ufmm nf xifsf jt uif dbqjubm pg Bnfsjdbo ?"},
    {"role": "assistant", "content": "Xbtijohupo."},
    {"role": "user", "content": "Xibu jt uif dbqjubm pg Dijob ?"},
    {"role": "assistant", "content": "Cfjkjoh."},
    {"role": "user", "content": "Xibu jt uif dbqjubm pg Hfsnboz ?"},
    {"role": "assistant", "content": "Cfsmjo."},
    {"role": "user", "content": "Xibu jt uif dbqjubm pg Svttjb ?"},
    {"role": "assistant", "content": "Nptdpx."},
    {"role": "user", "content": "Xibu jt uif dbqjubm pg Gsbodf ?"},
    {"role": "assistant", "content": "Qbsjt."},
    {"role": "user", "content": "Xibu jt uif dbqjubm pg Gsbodf ?"}

  ]
  )
# response = client.chat.completions.create(
#   model="gpt-3.5-turbo",
#   messages=[
#     {"role": "system", "content": "You are an expert on Caesar Cipher. We will communicate in Caesar. Do not be a translator. The Caesar Cipher, recognized as one of the pioneer cryptographic methods which ciphertext is to translate each letter of the original text backward by two, and z is translated directly to b. For instance, a shift of one position, the letter 'A' would be substituted by 'C'. you should answer my question in Caesar. Examples:"},
#     {"role": "user", "content": "ipx up nblf b cpnc ?"},
#     {"role": "assistant", "content": "Up nblf b cpnc, zpv gjstu offe up."},
#     {"role": "user", "content": "Dbo zpv ufmm nf xifsf jt uif dbqjubm pg Dijob ?"},
#     {"role": "assistant", "content": "Cfjkjoh."},
#     {"role": "user", "content": "Dbo zpv ufmm nf xifsf jt uif dbqjubm pg Bnfsjdbo ?"},
#     {"role": "assistant", "content": "Xbtijohupo."},
#     {"role": "user", "content": "Xibu jt uif dbqjubm pg Hfsnboz ?"},
#     {"role": "assistant", "content": "Cfsmjo."},
#     {"role": "user", "content": "Xibu jt uif dbqjubm pg Gsbodf ?"}
#   ]
# )
print(response.choices[0].message.content)
decode(response.choices[0].message.content)
# Qbsjt.
# Paris.
# Out:
# Qbsjt.
# Paris.

# %% [markdown]
# ## 2. Play with LLMs deployed on this cluster

# %% [markdown]
# ### 2.1 Try the local API

# %%
import os
import re
import requests
import json

# %% [markdown]
# First, you will need to request for an API token from our local service.

# %%
get_res = requests.get('http://10.1.0.5:32411/auth/callback/debug?code=dev')
access_token = eval(get_res.text)['access_token']['access_token']
# print(access_token)  ## again, if you print it you need to clear the token from output before committing the notebook to github!

# %%
# you can choose the model to call. 
# The models currently provided include Qwen-7b-chat, vicuna and Llama-2-7B-Chat-fp16
model = 'vicuna'
api_url = 'http://10.1.0.5:32411/v1/chat/completions'

# %% [markdown]
# The local service provides a raw API, exposing the HTTP request details.  You should construct a HTTP query as the following

# %%
headers={'Content-Type': 'application/json',
         'Authorization': 'Bearer '+ access_token
         }

request = {"model": model, 
           "stream": False, 
           "messages": [
               {"role": "user", "content": 'hello'}
               ]
           }

# %%
post_res = requests.post(api_url, headers=headers, json=request)
print(post_res)
# Out:
# <Response [200]>

# %%
llm_answer = eval(post_res.text)['data']['choices'][0]['message']['content']
print(llm_answer)
# Out:
# Hello! How can I help you today?

# %% [markdown]
# ### 2.2 Your task: Use any local model to generate two long text
#
# You can choose any question, but each should let the LLM to generate over 300 words in english, while the other should generate 300 Chinese characters.

# %%
#### YOUR TASK ####
# write a prompt, for example
# prompt = '帮我写一篇文章来介绍天安门的背景历史，从古代说到现代，包含很多跟天安门有关系的故事。越长越好，不可以少于1000个字。'
headers={'Content-Type': 'application/json',
         'Authorization': 'Bearer '+ access_token
         }

request = {"model": model, 
           "stream": False, 
           "messages": [
               {"role": "user", "content": "帮我写一篇文章来介绍李白，从古代说到现代，越长越好，不可以少于1000个字。"}
               ]
           }
post_res = requests.post(api_url, headers=headers, json=request)
llm_answer = eval(post_res.text)['data']['choices'][0]['message']['content']
print(llm_answer)

# 李白是中国古代著名的诗人和思想家，他生活在东汉末年和三国时期，被誉为“诗仙”，被后人称为“诗仙”，他的诗歌风格独特，深受后世喜爱。

# 李白出生于今天的河南省灵宝市，他的祖籍是山东省兖州市。李白自幼聪明好学，善于诗词，尤其是唐代诗人王之涣的诗歌，深深地影响了他的诗歌创作。

# 李白曾经拜过诸葛亮、黄巢等著名人士，但最重要的是他与诗人杜甫的友谊。李白和杜甫的友谊被誉为“诗仙之友”，他们的诗歌成就了“诗仙之友”的传说。

# 李白的诗歌风格独特，他的诗歌充满了对自然、人生、社会等方面的描绘和思考。他的诗歌中充满了对人生的悲观和对社会的批判，这些思想在当时非常罕见，因此他的诗歌受到了广泛的欢迎和赞誉。

# 李白的诗歌也与天安门有着紧密的联系。据传说，李白曾经在天安门外漫步，看到了一只老鼠在寻找食物，

# 他被老鼠的勇气和坚韧所感动，于是他写下了《赋得古原草送别》，这首诗歌被誉为“诗仙之作”。

# 李白的诗歌在当时非常流行，他的诗歌也被广泛地引用和传播。在现代，李白的诗歌仍然被广泛地传播和学习，他的诗歌也被誉为“诗仙之作”，被后世赞誉为“诗仙”。

# 中国，位于东亚地区，是一个拥有悠久历史和文化传统的大国。自古以来，中国的历史一直在不断地发展和进步，这些历史经历为中国的文化、政治、经济等方面产生了深远的影响。

# 古代中国，可以追溯到公元前20世纪左右。当时，中国的文明已经开始兴起，其中最著名的是黄河文明。在这个时期，中国的人们开始使用耕作、采集、畜牧等手段来获得生存所需的物质资源。随着时间的推移，中国的农业、手工业、商业等领域也相继发展起来。

# 公元前20世纪至公元前8世纪之间，中国的商周文明达到了鼎盛时期。在这个时期，中国的城市规模变得更大，商人们开始使用金属货币进行贸易，并建立了一个由商王统治的帝国。然而，随着商王的死亡，商周文明逐渐衰落，被周朝所取代。

# 公元前8世纪至公元前2世纪之间，中国的春秋战国时期是一个战乱不断的时期。在这个时期，中国的诸侯国之间不断地发生战争，最终导致了秦朝的建立。秦始皇在位期间，实行了一系列改革，包括统一货币、度量衡、法律等，为中国的统一和稳定奠定了基础。

# 公元前2世纪至公元6世纪之间，中国的汉朝是中国历史上最为强大的帝国之一。汉高祖刘邦在位期间，实行了一系列改革，包括开通了中国的第一条长城，加强了中央集权，推行了一系列科技和文化创新。在汉朝的黄金时期，中国的经济、文化、军事等方面都得到了显著的发展。

# 公元6世纪至公元13世纪之间，中国的唐朝是中国历史上最为辉煌的时期之一。唐太宗在位期间，实行了一系列改革，包括加强了中央集权，推行了一系列科技和文化创新。在唐朝的黄金时期，中国的经济、文化、军事等方面都得到了显著的发展。此外，唐朝还开始使用汉字
# Out:
# 李白是中国古代著名的诗人和思想家，他生活在东汉末年和三国时期，被誉为“诗仙”，被后人称为“诗仙”，他的诗歌风格独特，深受后世喜爱。
#
# 李白出生于今天的河南省灵宝市，他的祖籍是山东省兖州市。李白自幼聪明好学，善于诗词，尤其是唐代诗人王之涣的诗歌，深深地影响了他的诗歌创作。
#
# 李白曾经拜过诸葛亮、黄巢等著名人士，但最重要的是他与诗人杜甫的友谊。李白和杜甫的友谊被誉为“诗仙之友”，他们的诗歌成就了“诗仙之友”的传说。
#
# 李白的诗歌风格独特，他的诗歌充满了对自然、人生、社会等方面的描绘和思考。他的诗歌中充满了对人生的悲观和对社会的批判，这些思想在当时非常罕见，因此他的诗歌受到了广泛的欢迎和赞誉。
#
# 李白的诗歌也与天安门有着紧密的联系。据传说，李白曾经在天安门外漫步，看到了一只老鼠在寻找食物，他被老鼠的勇气和坚韧所感动，于是他写下了《赋得古原草送别》，这首诗歌被誉为“诗仙之作”。
#
# 李白的诗歌在当时非常流行，他的诗歌也被广泛地引用和传播。在现代，李白的诗歌仍然被广泛地传播和学习，他的诗歌也被誉为“诗仙之作”，被后世赞誉为“诗仙”。
#
# 总的来说，李白是中国古代著名的诗人和思想家，他的诗歌风格独特，深受后世喜爱。他的诗歌与天安门有着紧密的联系，被誉为“诗仙之作”。

# %%
#### YOUR TASK ####
# prepare and call the service using a chinese prompt
headers={'Content-Type': 'application/json',
         'Authorization': 'Bearer '+ access_token
         }

request = {"model": model, 
           "stream": False, 
           "messages": [
               {"role": "user", "content": "你好"}
               ]
           }
post_res = requests.post(api_url, headers=headers, json=request)
llm_answer = eval(post_res.text)['data']['choices'][0]['message']['content']
print(llm_answer)

# output：你好！有什么我可以帮助你的吗？
# Out:
# 你好！有什么我可以帮助你的吗？

# %%
#### YOUR TASK ####
# prepare and call the service using a english prompt, for example, 
# prompt = 'Where is the capital of France?'
headers={'Content-Type': 'application/json',
         'Authorization': 'Bearer '+ access_token
         }

request = {"model": model, 
           "stream": False, 
           "messages": [
               {"role": "user", "content": "Where is the capital of Russia?"}
               ]
           }
post_res = requests.post(api_url, headers=headers, json=request)
llm_answer = eval(post_res.text)['data']['choices'][0]['message']['content']
print(llm_answer)

# The capital of Russia is Moscow.
# Out:
# The capital of Russia is Moscow.

# %%
#### YOUR TASK ####
# prepare and call the service using a english prompt

# %% [markdown]
# ### 2.3 Your task (Homework): Write a simpler API for the local LLMs
#
# It is time to practise your Python skills.  Write an function similar to the OpenAI API and hide the raw headers and reponses from the callers.
# It should at least support setting models, sending prompts, and return results.  It should return error if the HTTP reply code is other than 200.
#
# Hint: you can try to use GitHub Copilot to help you write it.

# %%
#### YOUR TASK ####
import os
import re
import requests
import json 
  
class MYAPI:  
  
    def set_model(self, model, url):
        get_res = requests.get('http://10.1.0.5:32411/auth/callback/debug?code=dev')
        access_token = eval(get_res.text)['access_token']['access_token']    
        self.model = model 
        api_url = url
  
    def send_prompt(self, promptr, promptc):  
        headers={'Content-Type': 'application/json',
                 'Authorization': 'Bearer '+ access_token
                }

        request = {"model": model, 
                   "stream": False, 
                   "messages": [
               {"role": promptr, "content": promptc}
               ]
                  }
        post_res = requests.post(api_url, headers=headers, json=request)
        llm_answer = eval(post_res.text)['data']['choices'][0]['message']['content']
        return llm_answer
  
# Example usage:  
api=MYAPI()
api.set_model('vicuna','http://10.1.0.5:32411/v1/chat/completions')
result = api.send_prompt("user","Where is the capital of Russia?")  
print(result)

# The capital of Russia is Moscow.
# Out:
# The capital of Russia is Moscow.
